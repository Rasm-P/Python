# %%
from glob import glob
import pandas as pd

#1 For 2018 find the 10 countries with the highest military expenditure in USD
milit_files = glob('fac63dc3-30ad-4715-a313-a36063bdd7f9_Data.csv')
expenditure_csv = milit_files[0]
expenditures = pd.read_csv(expenditure_csv)
expenditures

df = expenditures.iloc[0:-52]
df = df[-df['2018 [YR2018]'].apply(lambda x: (x == '..'))]
df = df[df['2018 [YR2018]'].apply(lambda x: (x == x))]
df['2018 [YR2018]'] = df['2018 [YR2018]'].astype(float)
df = df.sort_values(by='2018 [YR2018]')

df['Country Name'].iloc[-10:]
# Out:
#                             Series Name     Series Code Country Name  \
# 32   Military expenditure (current USD)  MS.MIL.XPND.CD   Cabo Verde
# 71   Military expenditure (current USD)  MS.MIL.XPND.CD  Gambia, The
# 112  Military expenditure (current USD)  MS.MIL.XPND.CD      Liberia
# 193  Military expenditure (current USD)  MS.MIL.XPND.CD  Timor-Leste
# 169  Military expenditure (current USD)  MS.MIL.XPND.CD   Seychelles
# 19   Military expenditure (current USD)  MS.MIL.XPND.CD       Belize
#
#     Country Code    1990 [YR1990]     2000 [YR2000]     2010 [YR2010]  \
# 32           CPV               ..  6801072.79821535  8239369.29189467
# 71           GMB  3464911.1117034  3323532.17179142                ..
# 112          LBR               ..                ..           8458000
# 193          TLS               ..                ..          26389000
# 169          SYC  14840075.699376  10325841.5560868  7157559.78720231
# 19           BLZ          4768750           7116125          15337250
#
#         2011 [YR2011]     2012 [YR2012]     2013 [YR2013]     2014 [YR2014]  \
# 32   9757536.56239718  9736385.83866217  9815667.25947582  10049332.2103237
# 71                 ..  11173079.8607106  10378890.6934834  14599956.8686651
# 112          13271000          15179000          15111500          14531000
# 193          20530000          33388000          31683000          29624000
# 169   8712704.9511348   9924109.7489784  13766451.3239843  32597630.8150938
# 19           15416250          15219125          17778875          19916875
#
#         2015 [YR2015]    2016 [YR2016]     2017 [YR2017]  2018 [YR2018]  \
# 32   8922219.45508732  10171216.502214  9354384.16628162   1.071407e+07
# 71    14288131.905326               ..                ..   1.148722e+07
# 112          14799000         14712000          15334000   1.578650e+07
# 193          36959000         26217000          25442000   2.061000e+07
# 169  20616835.3810015   26718458.50436  22258545.4705701   2.282328e+07
# 19           19717625       21712887.5          23456750   2.308311e+07
#
#     2019 [YR2019]
# 32             ..
# 71             ..
# 112            ..
# 193            ..
# 169            ..
# 19             ..

# %%
#2 For 2018 find the 10 countries with the highest military expenditure per capita
